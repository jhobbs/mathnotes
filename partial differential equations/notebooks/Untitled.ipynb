# %%
# Import necessary libraries
from sage.symbolic.integration.integral import definite_integral
from sage.symbolic.ring import var

# Define the function and the variable
x = var('x', domain='real')
f = e**(3*x)  # Example function, you can replace it with any periodic function

# Define the period
T = 2 * pi  # Period of the function
L = T / 2

# Compute Fourier coefficients
a0 = (1 / L) * definite_integral(f, x, -L, L)
an = lambda n: (1 / L) * definite_integral(f * cos(n * pi * x / L), x, -L, L)
bn = lambda n: (1 / L) * definite_integral(f * sin(n * pi * x / L), x, -L, L)

m = var('m', domain='integer')

show(an(m) * cos(m * pi * x / L) + bn(m) * sin(m * pi * x / L))
# Construct the Fourier series
N = 10  # Number of terms in the Fourier series
fourier_series = a0 / 2 + sum(an(n) * cos(n * pi * x / L) + bn(n) * sin(n * pi * x / L) for n in range(1, N + 1))

show(fourier_series)

# Plot the original function and Fourier series
p1 = plot(f, (x, -L, L), color='red', legend_label='Original Function')
p2 = plot(fourier_series, (x, -L, L), color='blue', legend_label='Fourier Series (N=10)')

# Show the plot
(p1 + p2).show()
# Out:
# 3*((-1)^m*e^(3*pi)/(m^2 + 9) - (-1)^m/(m^2*e^(3*pi) + 9*e^(3*pi)))*cos(m*x)/pi - ((-1)^m*m*e^(3*pi)/(m^2 + 9) - (-1)^m*m/(m^2*e^(3*pi) + 9*e^(3*pi)))*sin(m*x)/pi
# 3/109*(e^(3*pi) - e^(-3*pi))*cos(10*x)/pi - 1/30*(e^(3*pi) - e^(-3*pi))*cos(9*x)/pi + 3/73*(e^(3*pi) - e^(-3*pi))*cos(8*x)/pi - 3/58*(e^(3*pi) - e^(-3*pi))*cos(7*x)/pi + 1/15*(e^(3*pi) - e^(-3*pi))*cos(6*x)/pi - 3/34*(e^(3*pi) - e^(-3*pi))*cos(5*x)/pi + 3/25*(e^(3*pi) - e^(-3*pi))*cos(4*x)/pi - 1/6*(e^(3*pi) - e^(-3*pi))*cos(3*x)/pi + 3/13*(e^(3*pi) - e^(-3*pi))*cos(2*x)/pi - 3/10*(e^(3*pi) - e^(-3*pi))*cos(x)/pi - 10/109*(e^(3*pi) - e^(-3*pi))*sin(10*x)/pi + 1/10*(e^(3*pi) - e^(-3*pi))*sin(9*x)/pi - 8/73*(e^(3*pi) - e^(-3*pi))*sin(8*x)/pi + 7/58*(e^(3*pi) - e^(-3*pi))*sin(7*x)/pi - 2/15*(e^(3*pi) - e^(-3*pi))*sin(6*x)/pi + 5/34*(e^(3*pi) - e^(-3*pi))*sin(5*x)/pi - 4/25*(e^(3*pi) - e^(-3*pi))*sin(4*x)/pi + 1/6*(e^(3*pi) - e^(-3*pi))*sin(3*x)/pi - 2/13*(e^(3*pi) - e^(-3*pi))*sin(2*x)/pi + 1/10*(e^(3*pi) - e^(-3*pi))*sin(x)/pi + 1/6*(e^(3*pi) - e^(-3*pi))/pi
# Graphics object consisting of 2 graphics primitives

# %%
# Define the function and variables
x = var('x')
n = var('n', domain='integer')  # For symbolic summation
L = pi  # Half of the period (adjust as needed for your function)

# Symbolic Fourier coefficients (not evaluated)
a0 = (1 / L) * integrate(x^2, (x, -L, L))
an = (1 / L) * integrate(x^2 * cos(n * pi * x / L), (x, -L, L))
bn = (1 / L) * integrate(x^2 * sin(n * pi * x / L), (x, -L, L))

# Symbolic Fourier series
N = 5  # Number of terms to show
fourier_series = a0 / 2 + sum(an * cos(n * pi * x / L) + bn * sin(n * pi * x / L) for n in range(1, N + 1))

# Display the symbolic Fourier series
fourier_series
# Out:
# 1/3*pi^2 + 4*(-1)^n*cos(5*x)/n^2 + 4*(-1)^n*cos(4*x)/n^2 + 4*(-1)^n*cos(3*x)/n^2 + 4*(-1)^n*cos(2*x)/n^2 + 4*(-1)^n*cos(x)/n^2

# %%
# Define the function and variables
x = var('x')
n = var('n', domain='integer')  # For symbolic summation
L = pi  # Half of the period (adjust as needed for your function)

# Symbolic Fourier coefficients (not evaluated)
a0 = (1 / L) * integrate(x^2, (x, -L, L))
an = (1 / L) * integrate(x^2 * cos(n * pi * x / L), (x, -L, L))
bn = (1 / L) * integrate(x^2 * sin(n * pi * x / L), (x, -L, L))

# Represent the Fourier series in summation form
fourier_series = a0 / 2 + sum(an * cos(n * pi * x / L) + bn * sin(n * pi * x / L), n, 1, oo)

# Display the symbolic Fourier series
show(fourier_series)
# Out:
# 1/3*pi^2 - 2*(I*imag_part(hypergeometric((1, 1, 1), (2, 2), -e^(I*x))) + I*imag_part(hypergeometric((1, 1, 1), (2, 2), -e^(-I*x))) + real_part(hypergeometric((1, 1, 1), (2, 2), -e^(I*x))) + real_part(hypergeometric((1, 1, 1), (2, 2), -e^(-I*x))))*cos(x) + 2*(imag_part(hypergeometric((1, 1, 1), (2, 2), -e^(I*x))) - imag_part(hypergeometric((1, 1, 1), (2, 2), -e^(-I*x))) - I*real_part(hypergeometric((1, 1, 1), (2, 2), -e^(I*x))) + I*real_part(hypergeometric((1, 1, 1), (2, 2), -e^(-I*x))))*sin(x)

# %%
# Define the function and variables
x = var('x')
n = var('n', domain='integer')  # For symbolic summation
L = pi  # Half of the period (adjust as needed for your function)

fun = e**(3*x)

# Symbolic Fourier coefficients (not evaluated)
a0 = (1 / L) * integrate(fun, (x, -L, L))
an = (1 / L) * integrate(fun * cos(n * pi * x / L), (x, -L, L)).simplify()
bn = (1 / L) * integrate(fun * sin(n * pi * x / L), (x, -L, L)).simplify()

# Represent the Fourier series in summation form
# Use explicit sums for clarity
fourier_series = a0 / 2 + sum(an * cos(n * pi * x / L) + bn * sin(n * pi * x / L), n, 1, oo)

show(fourier_series)

# Simplify and display the symbolic Fourier series
show(LatexExpr(r"\frac{" + str(a0) + "}{2} + \sum_{{n=1}}^{\infty} \left( " +
               str(an) + r"\cos\left(\frac{" + str(n) + r"\pi x}{" + str(L) + r"}\right)" +
               " + " +
               str(bn) + r"\sin\left(\frac{" + str(n) + r"\pi x}{" + str(L) + r"}\right)" +
               r"\right)"))
# Out:
# <>:20: DeprecationWarning: invalid escape sequence '\s'
# <>:20: DeprecationWarning: invalid escape sequence '\s'
# /tmp/ipykernel_956580/3390977822.py:20: DeprecationWarning: invalid escape sequence '\s'
#   show(LatexExpr(r"\frac{" + str(a0) + "}{2} + \sum_{{n=1}}^{\infty} \left( " +
# 1/20*(((e^(6*pi) - 1)*imag_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) - (e^(6*pi) - 1)*imag_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))) - 3*(I*e^(6*pi) - I)*imag_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) - 3*(I*e^(6*pi) - I)*imag_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))) + (-I*e^(6*pi) + I)*real_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) + (I*e^(6*pi) - I)*real_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))) - 3*(e^(6*pi) - 1)*real_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) - 3*(e^(6*pi) - 1)*real_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))))*cos(x) + ((I*e^(6*pi) - I)*imag_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) + (I*e^(6*pi) - I)*imag_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))) + 3*(e^(6*pi) - 1)*imag_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) - 3*(e^(6*pi) - 1)*imag_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))) + (e^(6*pi) - 1)*real_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) + (e^(6*pi) - 1)*real_part(hypergeometric((2, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))) - 3*(I*e^(6*pi) - I)*real_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(I*x))) - 3*(-I*e^(6*pi) + I)*real_part(hypergeometric((1, -3*I + 1, 3*I + 1), (-3*I + 2, 3*I + 2), -e^(-I*x))))*sin(x))*e^(-3*pi)/pi + 1/6*(e^(3*pi) - e^(-3*pi))/pi
# \frac{1/3*(e^(3*pi) - e^(-3*pi))/pi}{2} + \sum_{{n=1}}^{\infty} \left( 3*((-1)^n*e^(3*pi)/(n^2 + 9) - (-1)^n/(n^2*e^(3*pi) + 9*e^(3*pi)))/pi\cos\left(\frac{n\pi x}{pi}\right) + -((-1)^n*n*e^(3*pi)/(n^2 + 9) - (-1)^n*n/(n^2*e^(3*pi) + 9*e^(3*pi)))/pi\sin\left(\frac{n\pi x}{pi}\right)\right)

# %%
# Define variables
x, n = var('x n')
L = pi  # Half the period, you can adjust this according to your function's period

# Define a symbolic function f(x)
f = e**(3*x)

# Symbolic Fourier coefficients
a0 = (1 / L) * integral(f, (x, -L, L))
an = (1 / L) * integral(f * cos(n * pi * x / L), (x, -L, L))
bn = (1 / L) * integral(f * sin(n * pi * x / L), (x, -L, L))

# Create the LaTeX expression for the Fourier series
fourier_series_latex = LatexExpr(r"a_0/2 + \sum_{n=1}^\infty \left( a_n \cos\left(\frac{n \pi x}{L}\right) + b_n \sin\left(\frac{n \pi x}{L}\right) \right)")

# Substitute symbols with their definitions
fourier_series_latex = fourier_series_latex.subs(a0=a0, an=an, bn=bn)

# Display the formatted Fourier series
show(fourier_series_latex)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_956580/1434941035.py in <module>
#      15
#      16 # Substitute symbols with their definitions
# ---> 17 fourier_series_latex = fourier_series_latex.subs(a0=a0, an=an, bn=bn)
#      18
#      19 # Display the formatted Fourier series
#
# AttributeError: 'LatexExpr' object has no attribute 'subs'
